# %% [markdown]
# # Import Libraries

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import torch
import torchvision
from torch import nn
import matplotlib.pyplot as plt
from PIL import Image
from torch.utils.data import Dataset as Dataset
from torch.utils.data import DataLoader
from torchvision import transforms as tt
from sklearn.utils import shuffle
import torchinfo
from tqdm import tqdm
import warnings
warnings.filterwarnings("ignore")

try:
    import torchmetrics
except:
    # !pip install torchmetrics
    
from torchmetrics import Accuracy

height, width = 224, 224
# Out:
# Collecting torchmetrics
#   Downloading torchmetrics-0.11.4-py3-none-any.whl (519 kB)
#      -------------------------------------- 519.2/519.2 kB 1.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17.2 in c:\users\axcel\anaconda3\envs\dl\lib\site-packages (from torchmetrics) (1.21.6)
# Requirement already satisfied: torch>=1.8.1 in c:\users\axcel\anaconda3\envs\dl\lib\site-packages (from torchmetrics) (1.12.1)
# Requirement already satisfied: packaging in c:\users\axcel\anaconda3\envs\dl\lib\site-packages (from torchmetrics) (23.1)
# Requirement already satisfied: typing-extensions in c:\users\axcel\anaconda3\envs\dl\lib\site-packages (from torchmetrics) (4.7.1)
# Installing collected packages: torchmetrics
# Successfully installed torchmetrics-0.11.4

# %% [markdown]
# ### Let's check if GPU is available too.

# %%
if torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')
    
device
# Out:
# device(type='cpu')

# %% [markdown]
# # Data Engineering

# %% [markdown]
# ### A lot of the work when it comes to Deep Learning revolves around engineering the data and making it to exactly the format that is useful to us.

# %%
# Create training transform with TrivialAugment
train_transform_trivial_augment = tt.Compose([
    tt.Resize((height, width)),
    tt.TrivialAugmentWide(num_magnitude_bins=31),
    tt.ToTensor() 
])

# Create testing transform (no data augmentation)
test_transform = tt.Compose([
    tt.Resize((height, width)),
    tt.ToTensor()
])

# %% [markdown]
# ### Now we have to split up the files to have train and test datasets.

# %%
from glob import glob
non_vehicles = glob('data/non-vehicles/*')
non_vehicles = non_vehicles[:8960]

vehicles = glob('data/vehicles/*')
vehicles = vehicles[:8768]

non_vehicles_train = non_vehicles[:6272]
non_vehicles_test = non_vehicles[6272:]

vehicles_train = vehicles[:6000]
vehicles_test = vehicles[6000:]

# %% [markdown]
# ### Time to make our custom dataset.

# %%
class VehicleDetection(Dataset):
    def __init__(self, transform, non_vehicles, vehicles):
        self.non_vehicles = non_vehicles
        self.vehicles = vehicles
        self.transform = transform
        
        labels = [[1,0] for i in range(len(non_vehicles))]
        labels += [[0,1] for i in range(len(vehicles))]
        
        image_links = self.non_vehicles + self.vehicles
        
        self.df = pd.DataFrame({
            'image': image_links,
            'labels': labels
        })
        
        
    def __len__(self):
        return len(self.non_vehicles) + len(self.vehicles)
    
    def __getitem__(self, idx):
        
        image_list = self.df['image'][idx]
        label_list = self.df['labels'][idx]
        
        if type(image_list) == str:
            image_list = [image_list]

        if not isinstance(label_list,np.int64):
            label_list = torch.tensor(label_list, dtype=torch.float)
            
        for image in image_list:
            img = Image.open(image)
            
        return self.transform(img), label_list

# %%
train_data_custom = VehicleDetection(train_transform_trivial_augment, non_vehicles_train, vehicles_train)
test_data_custom = VehicleDetection(test_transform, non_vehicles_test, vehicles_test)

# %%
print(f"We have {len(train_data_custom)} training datapoints and {len(test_data_custom)} testing datapoints")
# Out:
# We have 12272 training datapoints and 5456 testing datapoints

# %% [markdown]
# ### Let's make our **custom dataloaders** now.

# %%
train_dataloader_custom = DataLoader(dataset=train_data_custom, # use custom created train Dataset
                                     batch_size=32, # how many samples per batch?
                                     num_workers=2, # how many subprocesses to use for data loading? (higher = more)
                                     shuffle=True) # shuffle the data?

test_dataloader_custom = DataLoader(dataset=test_data_custom, # use custom created test Dataset
                                    batch_size=32, 
                                    num_workers=2, 
                                    shuffle=False)

train_dataloader_custom, test_dataloader_custom
# Out:
# (<torch.utils.data.dataloader.DataLoader at 0x27336028988>,
#  <torch.utils.data.dataloader.DataLoader at 0x27336028948>)

# %% [markdown]
# ### Let's check whether it is working correctly.

# %%
img_custom, label_custom = next(iter(train_dataloader_custom))

print(f"Image shape: {img_custom.shape} -> [batch_size, color_channels, height, width]")
print(f"Label shape: {label_custom.shape}")
# Out:
# ---------------------------------------------------------------------------
# BrokenPipeError                           Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19120\36851985.py in <module>
# ----> 1 img_custom, label_custom = next(iter(train_dataloader_custom))
#       2
#       3 print(f"Image shape: {img_custom.shape} -> [batch_size, color_channels, height, width]")
#       4 print(f"Label shape: {label_custom.shape}")
#
# ~\anaconda3\envs\DL\lib\site-packages\torch\utils\data\dataloader.py in __iter__(self)
#     442             return self._iterator
#     443         else:
# --> 444             return self._get_iterator()
#     445
#     446     @property
#
# ~\anaconda3\envs\DL\lib\site-packages\torch\utils\data\dataloader.py in _get_iterator(self)
#     388         else:
#     389             self.check_worker_number_rationality()
# --> 390             return _MultiProcessingDataLoaderIter(self)
#     391
#     392     @property
#
# ~\anaconda3\envs\DL\lib\site-packages\torch\utils\data\dataloader.py in __init__(self, loader)
#    1075             #     before it starts, and __del__ tries to join but will get:
#    1076             #     AssertionError: can only join a started process.
# -> 1077             w.start()
#    1078             self._index_queues.append(index_queue)
#    1079             self._workers.append(w)
#
# ~\anaconda3\envs\DL\lib\multiprocessing\process.py in start(self)
#     110                'daemonic processes are not allowed to have children'
#     111         _cleanup()
# --> 112         self._popen = self._Popen(self)
#     113         self._sentinel = self._popen.sentinel
#     114         # Avoid a refcycle if the target function holds an indirect
#
# ~\anaconda3\envs\DL\lib\multiprocessing\context.py in _Popen(process_obj)
#     221     @staticmethod
#     222     def _Popen(process_obj):
# --> 223         return _default_context.get_context().Process._Popen(process_obj)
#     224
#     225 class DefaultContext(BaseContext):
#
# ~\anaconda3\envs\DL\lib\multiprocessing\context.py in _Popen(process_obj)
#     320         def _Popen(process_obj):
#     321             from .popen_spawn_win32 import Popen
# --> 322             return Popen(process_obj)
#     323
#     324     class SpawnContext(BaseContext):
#
# ~\anaconda3\envs\DL\lib\multiprocessing\popen_spawn_win32.py in __init__(self, process_obj)
#      87             try:
#      88                 reduction.dump(prep_data, to_child)
# ---> 89                 reduction.dump(process_obj, to_child)
#      90             finally:
#      91                 set_spawning_popen(None)
#
# ~\anaconda3\envs\DL\lib\multiprocessing\reduction.py in dump(obj, file, protocol)
#      58 def dump(obj, file, protocol=None):
#      59     '''Replacement for pickle.dump() using ForkingPickler.'''
# ---> 60     ForkingPickler(file, protocol).dump(obj)
#      61
#      62 #
#
# BrokenPipeError: [Errno 32] Broken pipe

# %% [markdown]
# ### Let's check whether any of our images have a different number of color channels.
# ### There could be some erreneous images along the way with only a single color channel.

# %%
"""count = 0

for batch, (X,y) in enumerate(train_dataloader_custom):
    if (X.shape[1] != 3):
        count += 1
        
for batch, (X,y) in enumerate(test_dataloader_custom):
    if (X.shape[1] != 3):
        count += 1
        
print(count)
print(f"\nThere are {count/(len(train_dataloader_custom) + len(test_dataloader_custom))*100:.1f}% of errenous pictures")"""
# Out:
# 'count = 0\n\nfor batch, (X,y) in enumerate(train_dataloader_custom):\n    if (X.shape[1] != 3):\n        count += 1\n        \nfor batch, (X,y) in enumerate(test_dataloader_custom):\n    if (X.shape[1] != 3):\n        count += 1\n        \nprint(count)\nprint(f"\nThere are {count/(len(train_dataloader_custom) + len(test_dataloader_custom))*100:.1f}% of errenous pictures")'

# %% [markdown]
# ### Luckily for us, there seems to be no errors in the data.
# ### Let's proceed on with importing our model to use.

# %% [markdown]
# # Basic CNN

# %% [markdown]
# ### Let's first take a look at the performance of a basic CNN model.

# %%
class Basic_CNN(nn.Module):
    def __init__(self, input_shape, hidden_shape, output_shape):
        super().__init__()
        self.conv_1 = nn.Sequential(
            nn.Conv2d(input_shape, hidden_shape, 3, 1, 1), # hidden * 224 * 224
            nn.ReLU(),
            nn.Conv2d(hidden_shape, hidden_shape, 3, 1, 1), # hidden * 224 * 224
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, # hidden * 112 * 112 
                         stride=2)
        )
        
        self.conv_2 = nn.Sequential(
            nn.Conv2d(hidden_shape, hidden_shape, 3, 1, 1), # hidden * 112 * 112 
            nn.ReLU(),
            nn.Conv2d(hidden_shape, hidden_shape, 3, 1, 1), # hidden * 112 * 112 
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, # hidden * 56 * 56 
                         stride=2)
        )
        
        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(hidden_shape * 56 * 56, output_shape)
        )
        
    def forward(self, x):
        return self.classifier(self.conv_2(self.conv_1(x)))
    
torch.manual_seed(42)
basic_model = Basic_CNN(3,32,2)
basic_model.to(device)
# Out:
# Basic_CNN(
#   (conv_1): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv_2): Sequential(
#     (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=100352, out_features=2, bias=True)
#   )
# )

# %%
# Setup loss function and optimizer
model = basic_model
lf = nn.BCEWithLogitsLoss()
optimizer = torch.optim.SGD(params=model.parameters(), lr=0.001)

epochs = 100
acc_fn = Accuracy(task='binary').to(device)
train_loss_arr = []
test_loss_arr = []
test_acc_arr = []

for epoch in range(epochs):
    train_loss = 0
    
    for batch, (X,y) in enumerate(train_dataloader_custom):
            
        X = X.to(device)
        y = y.to(device)
        model.train()
        
        # Forward
        y_pred = model(X)
        
        # Calculate loss
        loss = lf(y_pred, y)
        train_loss += loss
        
        # Zero grad
        optimizer.zero_grad()
        
        # Loss backward
        loss.backward()
        
        # Optimizer step
        optimizer.step()
    
    train_loss/=len(train_dataloader_custom)
    train_loss_arr.append(train_loss.cpu().detach().numpy())
    
    test_loss, test_acc= 0, 0
    model.eval() 
    with torch.inference_mode():
        for batch, (X,y) in enumerate(test_dataloader_custom):
            
            X = X.to(device)
            y = y.to(device)
            
            # Forward
            test_pred = model(X)
            
            # Calculate loss 
            test_loss += lf(test_pred, y)
            
            # Calculate accuracy 
            acc_fn.update(test_pred.argmax(dim=1).to(device), y.argmax(dim=1).to(device))
            test_acc += acc_fn.compute()
            
        test_loss /= len(test_dataloader_custom)
        test_loss_arr.append(test_loss.cpu().detach().numpy())
        test_acc /= len(test_dataloader_custom)
        test_acc_arr.append(test_acc.cpu().detach().numpy())
        
    print(f"\nEpoch: {epoch} | Train loss: {train_loss:.5f} | Test loss: {test_loss:.5f}, Test acc: {test_acc*100:.2f}%\n")
# Out:
# Epoch: 0 | Train loss: 0.69277 | Test loss: 0.69249, Test acc: 83.89%
#
#
# Epoch: 1 | Train loss: 0.69158 | Test loss: 0.69122, Test acc: 57.75%
#
#
# Epoch: 2 | Train loss: 0.68923 | Test loss: 0.68664, Test acc: 54.59%
#
#
# Epoch: 3 | Train loss: 0.68421 | Test loss: 0.67806, Test acc: 56.29%
#
#
# Epoch: 4 | Train loss: 0.67167 | Test loss: 0.65263, Test acc: 57.10%
#
#
# Epoch: 5 | Train loss: 0.64150 | Test loss: 0.60035, Test acc: 59.33%
#
#
# Epoch: 6 | Train loss: 0.60327 | Test loss: 0.54723, Test acc: 60.94%
#
#
# Epoch: 7 | Train loss: 0.57384 | Test loss: 0.51545, Test acc: 62.89%
#
#
# Epoch: 8 | Train loss: 0.55325 | Test loss: 0.48390, Test acc: 64.47%
#
#
# Epoch: 9 | Train loss: 0.52803 | Test loss: 0.44618, Test acc: 65.94%
#
#
# Epoch: 10 | Train loss: 0.49606 | Test loss: 0.40599, Test acc: 67.61%
#
#
# Epoch: 11 | Train loss: 0.47294 | Test loss: 0.37475, Test acc: 69.09%
#
#
# Epoch: 12 | Train loss: 0.44849 | Test loss: 0.35696, Test acc: 70.27%
#
#
# Epoch: 13 | Train loss: 0.43858 | Test loss: 0.34038, Test acc: 71.57%
#
#
# Epoch: 14 | Train loss: 0.43334 | Test loss: 0.32564, Test acc: 72.42%
#
#
# Epoch: 15 | Train loss: 0.42534 | Test loss: 0.32004, Test acc: 73.33%
#
#
# Epoch: 16 | Train loss: 0.41822 | Test loss: 0.30754, Test acc: 74.22%
#
#
# Epoch: 17 | Train loss: 0.41470 | Test loss: 0.30113, Test acc: 75.00%
#
#
# Epoch: 18 | Train loss: 0.39947 | Test loss: 0.31094, Test acc: 75.77%
#
#
# Epoch: 19 | Train loss: 0.39348 | Test loss: 0.31863, Test acc: 76.14%
#
#
# Epoch: 20 | Train loss: 0.39207 | Test loss: 0.30337, Test acc: 76.85%
#
#
# Epoch: 21 | Train loss: 0.38170 | Test loss: 0.27323, Test acc: 77.30%
#
#
# Epoch: 22 | Train loss: 0.37318 | Test loss: 0.26885, Test acc: 77.88%
#
#
# Epoch: 23 | Train loss: 0.37408 | Test loss: 0.26114, Test acc: 78.37%
#
#
# Epoch: 24 | Train loss: 0.36527 | Test loss: 0.25929, Test acc: 78.83%
#
#
# Epoch: 25 | Train loss: 0.35560 | Test loss: 0.25060, Test acc: 79.31%
#
#
# Epoch: 26 | Train loss: 0.35183 | Test loss: 0.26016, Test acc: 79.67%
#
#
# Epoch: 27 | Train loss: 0.34837 | Test loss: 0.25855, Test acc: 80.13%
#
#
# Epoch: 28 | Train loss: 0.33637 | Test loss: 0.24833, Test acc: 80.47%
#
#
# Epoch: 29 | Train loss: 0.34080 | Test loss: 0.23533, Test acc: 80.80%
#
#
# Epoch: 30 | Train loss: 0.32806 | Test loss: 0.23031, Test acc: 81.14%
#
#
# Epoch: 31 | Train loss: 0.32656 | Test loss: 0.21710, Test acc: 81.46%
#
#
# Epoch: 32 | Train loss: 0.32092 | Test loss: 0.23299, Test acc: 81.81%
#
#
# Epoch: 33 | Train loss: 0.31307 | Test loss: 0.20479, Test acc: 82.07%
#
#
# Epoch: 34 | Train loss: 0.30799 | Test loss: 0.20460, Test acc: 82.40%
#
#
# Epoch: 35 | Train loss: 0.29974 | Test loss: 0.19634, Test acc: 82.69%
#
#
# Epoch: 36 | Train loss: 0.30576 | Test loss: 0.19356, Test acc: 82.99%
#
#
# Epoch: 37 | Train loss: 0.29764 | Test loss: 0.18817, Test acc: 83.29%
#
#
# Epoch: 38 | Train loss: 0.29056 | Test loss: 0.18442, Test acc: 83.57%
#
#
# Epoch: 39 | Train loss: 0.28900 | Test loss: 0.18052, Test acc: 83.83%
#
#
# Epoch: 40 | Train loss: 0.28628 | Test loss: 0.17374, Test acc: 84.07%
#
#
# Epoch: 41 | Train loss: 0.28100 | Test loss: 0.16864, Test acc: 84.33%
#
#
# Epoch: 42 | Train loss: 0.27642 | Test loss: 0.18983, Test acc: 84.54%
#
#
# Epoch: 43 | Train loss: 0.27155 | Test loss: 0.16983, Test acc: 84.77%
#
#
# Epoch: 44 | Train loss: 0.26914 | Test loss: 0.16663, Test acc: 85.01%
#
#
# Epoch: 45 | Train loss: 0.27071 | Test loss: 0.16101, Test acc: 85.22%
#
#
# Epoch: 46 | Train loss: 0.27375 | Test loss: 0.16180, Test acc: 85.43%
#
#
# Epoch: 47 | Train loss: 0.26671 | Test loss: 0.16350, Test acc: 85.63%
#
#
# Epoch: 48 | Train loss: 0.25947 | Test loss: 0.16080, Test acc: 85.80%
#
#
# Epoch: 49 | Train loss: 0.26482 | Test loss: 0.24090, Test acc: 85.96%
#
#
# Epoch: 50 | Train loss: 0.25784 | Test loss: 0.15534, Test acc: 86.06%
#
#
# Epoch: 51 | Train loss: 0.26311 | Test loss: 0.14543, Test acc: 86.23%
#
#
# Epoch: 52 | Train loss: 0.24711 | Test loss: 0.15274, Test acc: 86.42%
#
#
# Epoch: 53 | Train loss: 0.24642 | Test loss: 0.19029, Test acc: 86.52%
#
#
# Epoch: 54 | Train loss: 0.24306 | Test loss: 0.14169, Test acc: 86.70%
#
#
# Epoch: 55 | Train loss: 0.23692 | Test loss: 0.13617, Test acc: 86.87%
#
#
# Epoch: 56 | Train loss: 0.24118 | Test loss: 0.13120, Test acc: 87.02%
#
#
# Epoch: 57 | Train loss: 0.23811 | Test loss: 0.14002, Test acc: 87.18%
#
#
# Epoch: 58 | Train loss: 0.23885 | Test loss: 0.15749, Test acc: 87.33%
#
#
# Epoch: 59 | Train loss: 0.23799 | Test loss: 0.17477, Test acc: 87.45%
#
#
# Epoch: 60 | Train loss: 0.23335 | Test loss: 0.12922, Test acc: 87.55%
#
#
# Epoch: 61 | Train loss: 0.23127 | Test loss: 0.18655, Test acc: 87.63%
#
#
# Epoch: 62 | Train loss: 0.23098 | Test loss: 0.13256, Test acc: 87.77%
#
#
# Epoch: 63 | Train loss: 0.22157 | Test loss: 0.12584, Test acc: 87.89%
#
#
# Epoch: 64 | Train loss: 0.22747 | Test loss: 0.13137, Test acc: 88.03%
#
#
# Epoch: 65 | Train loss: 0.23265 | Test loss: 0.12579, Test acc: 88.16%
#
#
# Epoch: 66 | Train loss: 0.22061 | Test loss: 0.12135, Test acc: 88.28%
#
#
# Epoch: 67 | Train loss: 0.21665 | Test loss: 0.13056, Test acc: 88.40%
#
#
# Epoch: 68 | Train loss: 0.22019 | Test loss: 0.12555, Test acc: 88.51%
#
#
# Epoch: 69 | Train loss: 0.21981 | Test loss: 0.11287, Test acc: 88.61%
#
#
# Epoch: 70 | Train loss: 0.21000 | Test loss: 0.13526, Test acc: 88.73%
#
#
# Epoch: 71 | Train loss: 0.21115 | Test loss: 0.19342, Test acc: 88.76%
#
#
# Epoch: 72 | Train loss: 0.21321 | Test loss: 0.14619, Test acc: 88.83%
#
#
# Epoch: 73 | Train loss: 0.21211 | Test loss: 0.11048, Test acc: 88.93%
#
#
# Epoch: 74 | Train loss: 0.21003 | Test loss: 0.10959, Test acc: 89.04%
#
#
# Epoch: 75 | Train loss: 0.20743 | Test loss: 0.11831, Test acc: 89.15%
#
#
# Epoch: 76 | Train loss: 0.20039 | Test loss: 0.10824, Test acc: 89.24%
#
#
# Epoch: 77 | Train loss: 0.20690 | Test loss: 0.11218, Test acc: 89.33%
#
#
# Epoch: 78 | Train loss: 0.20278 | Test loss: 0.12080, Test acc: 89.43%
#
#
# Epoch: 79 | Train loss: 0.19132 | Test loss: 0.10359, Test acc: 89.52%
#
#
# Epoch: 80 | Train loss: 0.19528 | Test loss: 0.11531, Test acc: 89.61%
#
#
# Epoch: 81 | Train loss: 0.20020 | Test loss: 0.10777, Test acc: 89.70%
#
#
# Epoch: 82 | Train loss: 0.19599 | Test loss: 0.10455, Test acc: 89.78%
#
#
# Epoch: 83 | Train loss: 0.19217 | Test loss: 0.14612, Test acc: 89.87%
#
#
# Epoch: 84 | Train loss: 0.18253 | Test loss: 0.12630, Test acc: 89.93%
#
#
# Epoch: 85 | Train loss: 0.18114 | Test loss: 0.11385, Test acc: 89.98%
#
#
# Epoch: 86 | Train loss: 0.18401 | Test loss: 0.11278, Test acc: 90.06%
#
#
# Epoch: 87 | Train loss: 0.18408 | Test loss: 0.11601, Test acc: 90.14%
#
#
# Epoch: 88 | Train loss: 0.18008 | Test loss: 0.12676, Test acc: 90.21%
#
#
# Epoch: 89 | Train loss: 0.18458 | Test loss: 0.11124, Test acc: 90.27%
#
#
# Epoch: 90 | Train loss: 0.18513 | Test loss: 0.09636, Test acc: 90.34%
#
#
# Epoch: 91 | Train loss: 0.18193 | Test loss: 0.10935, Test acc: 90.42%
#
#
# Epoch: 92 | Train loss: 0.18538 | Test loss: 0.11142, Test acc: 90.49%
#
#
# Epoch: 93 | Train loss: 0.17561 | Test loss: 0.11179, Test acc: 90.55%
#
#
# Epoch: 94 | Train loss: 0.17655 | Test loss: 0.12299, Test acc: 90.62%
#
#
# Epoch: 95 | Train loss: 0.17238 | Test loss: 0.09210, Test acc: 90.67%
#
#
# Epoch: 96 | Train loss: 0.17593 | Test loss: 0.09201, Test acc: 90.74%
#
#
# Epoch: 97 | Train loss: 0.16770 | Test loss: 0.23264, Test acc: 90.80%
#
#
# Epoch: 98 | Train loss: 0.17570 | Test loss: 0.09099, Test acc: 90.82%
#
#
# Epoch: 99 | Train loss: 0.17354 | Test loss: 0.10339, Test acc: 90.89%

# %%
plt.plot([i for i in range(epochs)], train_loss_arr, label='train loss')
plt.plot([i for i in range(epochs)], test_loss_arr, label='test loss')
plt.plot([i for i in range(epochs)], test_acc_arr, label='test accuracy')
plt.title('Evaluation')
plt.xlabel('Epochs')
plt.ylabel('Values')
plt.legend();

# %% [markdown]
# # Transfer Learning

# %% [markdown]
# ### I'm going to be using the ResNet50 pretrained model from PyTorch.

# %%
weights = torchvision.models.ResNet50_Weights.DEFAULT 
model = torchvision.models.resnet50(weights=weights).to(device)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-11ad3fa6.pth" to /root/.cache/torch/hub/checkpoints/resnet50-11ad3fa6.pth
#   0%|          | 0.00/97.8M [00:00<?, ?B/s]

# %% [markdown]
# ### Let's see how our model looks like.

# %%
torchinfo.summary(model=model, 
        input_size=(32, 3, 224, 224),
        col_names=["input_size", "output_size", "num_params", "trainable"],
        col_width=20,
        row_settings=["var_names"]
)
# Out:
# ========================================================================================================================
# Layer (type (var_name))                  Input Shape          Output Shape         Param #              Trainable
# ========================================================================================================================
# ResNet (ResNet)                          [32, 3, 224, 224]    [32, 1000]           --                   True
# ├─Conv2d (conv1)                         [32, 3, 224, 224]    [32, 64, 112, 112]   9,408                True
# ├─BatchNorm2d (bn1)                      [32, 64, 112, 112]   [32, 64, 112, 112]   128                  True
# ├─ReLU (relu)                            [32, 64, 112, 112]   [32, 64, 112, 112]   --                   --
# ├─MaxPool2d (maxpool)                    [32, 64, 112, 112]   [32, 64, 56, 56]     --                   --
# ├─Sequential (layer1)                    [32, 64, 56, 56]     [32, 256, 56, 56]    --                   True
# │    └─Bottleneck (0)                    [32, 64, 56, 56]     [32, 256, 56, 56]    --                   True
# │    │    └─Conv2d (conv1)               [32, 64, 56, 56]     [32, 64, 56, 56]     4,096                True
# │    │    └─BatchNorm2d (bn1)            [32, 64, 56, 56]     [32, 64, 56, 56]     128                  True
# │    │    └─ReLU (relu)                  [32, 64, 56, 56]     [32, 64, 56, 56]     --                   --
# │    │    └─Conv2d (conv2)               [32, 64, 56, 56]     [32, 64, 56, 56]     36,864               True
# │    │    └─BatchNorm2d (bn2)            [32, 64, 56, 56]     [32, 64, 56, 56]     128                  True
# │    │    └─ReLU (relu)                  [32, 64, 56, 56]     [32, 64, 56, 56]     --                   --
# │    │    └─Conv2d (conv3)               [32, 64, 56, 56]     [32, 256, 56, 56]    16,384               True
# │    │    └─BatchNorm2d (bn3)            [32, 256, 56, 56]    [32, 256, 56, 56]    512                  True
# │    │    └─Sequential (downsample)      [32, 64, 56, 56]     [32, 256, 56, 56]    16,896               True
# │    │    └─ReLU (relu)                  [32, 256, 56, 56]    [32, 256, 56, 56]    --                   --
# │    └─Bottleneck (1)                    [32, 256, 56, 56]    [32, 256, 56, 56]    --                   True
# │    │    └─Conv2d (conv1)               [32, 256, 56, 56]    [32, 64, 56, 56]     16,384               True
# │    │    └─BatchNorm2d (bn1)            [32, 64, 56, 56]     [32, 64, 56, 56]     128                  True
# │    │    └─ReLU (relu)                  [32, 64, 56, 56]     [32, 64, 56, 56]     --                   --
# │    │    └─Conv2d (conv2)               [32, 64, 56, 56]     [32, 64, 56, 56]     36,864               True
# │    │    └─BatchNorm2d (bn2)            [32, 64, 56, 56]     [32, 64, 56, 56]     128                  True
# │    │    └─ReLU (relu)                  [32, 64, 56, 56]     [32, 64, 56, 56]     --                   --
# │    │    └─Conv2d (conv3)               [32, 64, 56, 56]     [32, 256, 56, 56]    16,384               True
# │    │    └─BatchNorm2d (bn3)            [32, 256, 56, 56]    [32, 256, 56, 56]    512                  True
# │    │    └─ReLU (relu)                  [32, 256, 56, 56]    [32, 256, 56, 56]    --                   --
# │    └─Bottleneck (2)                    [32, 256, 56, 56]    [32, 256, 56, 56]    --                   True
# │    │    └─Conv2d (conv1)               [32, 256, 56, 56]    [32, 64, 56, 56]     16,384               True
# │    │    └─BatchNorm2d (bn1)            [32, 64, 56, 56]     [32, 64, 56, 56]     128                  True
# │    │    └─ReLU (relu)                  [32, 64, 56, 56]     [32, 64, 56, 56]     --                   --
# │    │    └─Conv2d (conv2)               [32, 64, 56, 56]     [32, 64, 56, 56]     36,864               True
# │    │    └─BatchNorm2d (bn2)            [32, 64, 56, 56]     [32, 64, 56, 56]     128                  True
# │    │    └─ReLU (relu)                  [32, 64, 56, 56]     [32, 64, 56, 56]     --                   --
# │    │    └─Conv2d (conv3)               [32, 64, 56, 56]     [32, 256, 56, 56]    16,384               True
# │    │    └─BatchNorm2d (bn3)            [32, 256, 56, 56]    [32, 256, 56, 56]    512                  True
# │    │    └─ReLU (relu)                  [32, 256, 56, 56]    [32, 256, 56, 56]    --                   --
# ├─Sequential (layer2)                    [32, 256, 56, 56]    [32, 512, 28, 28]    --                   True
# │    └─Bottleneck (0)                    [32, 256, 56, 56]    [32, 512, 28, 28]    --                   True
# │    │    └─Conv2d (conv1)               [32, 256, 56, 56]    [32, 128, 56, 56]    32,768               True
# │    │    └─BatchNorm2d (bn1)            [32, 128, 56, 56]    [32, 128, 56, 56]    256                  True
# │    │    └─ReLU (relu)                  [32, 128, 56, 56]    [32, 128, 56, 56]    --                   --
# │    │    └─Conv2d (conv2)               [32, 128, 56, 56]    [32, 128, 28, 28]    147,456              True
# │    │    └─BatchNorm2d (bn2)            [32, 128, 28, 28]    [32, 128, 28, 28]    256                  True
# │    │    └─ReLU (relu)                  [32, 128, 28, 28]    [32, 128, 28, 28]    --                   --
# │    │    └─Conv2d (conv3)               [32, 128, 28, 28]    [32, 512, 28, 28]    65,536               True
# │    │    └─BatchNorm2d (bn3)            [32, 512, 28, 28]    [32, 512, 28, 28]    1,024                True
# │    │    └─Sequential (downsample)      [32, 256, 56, 56]    [32, 512, 28, 28]    132,096              True
# │    │    └─ReLU (relu)                  [32, 512, 28, 28]    [32, 512, 28, 28]    --                   --
# │    └─Bottleneck (1)                    [32, 512, 28, 28]    [32, 512, 28, 28]    --                   True
# │    │    └─Conv2d (conv1)               [32, 512, 28, 28]    [32, 128, 28, 28]    65,536               True
# │    │    └─BatchNorm2d (bn1)            [32, 128, 28, 28]    [32, 128, 28, 28]    256                  True
# │    │    └─ReLU (relu)                  [32, 128, 28, 28]    [32, 128, 28, 28]    --                   --
# │    │    └─Conv2d (conv2)               [32, 128, 28, 28]    [32, 128, 28, 28]    147,456              True
# │    │    └─BatchNorm2d (bn2)            [32, 128, 28, 28]    [32, 128, 28, 28]    256                  True
# │    │    └─ReLU (relu)                  [32, 128, 28, 28]    [32, 128, 28, 28]    --                   --
# │    │    └─Conv2d (conv3)               [32, 128, 28, 28]    [32, 512, 28, 28]    65,536               True
# │    │    └─BatchNorm2d (bn3)            [32, 512, 28, 28]    [32, 512, 28, 28]    1,024                True
# │    │    └─ReLU (relu)                  [32, 512, 28, 28]    [32, 512, 28, 28]    --                   --
# │    └─Bottleneck (2)                    [32, 512, 28, 28]    [32, 512, 28, 28]    --                   True
# │    │    └─Conv2d (conv1)               [32, 512, 28, 28]    [32, 128, 28, 28]    65,536               True
# │    │    └─BatchNorm2d (bn1)            [32, 128, 28, 28]    [32, 128, 28, 28]    256                  True
# │    │    └─ReLU (relu)                  [32, 128, 28, 28]    [32, 128, 28, 28]    --                   --
# │    │    └─Conv2d (conv2)               [32, 128, 28, 28]    [32, 128, 28, 28]    147,456              True
# │    │    └─BatchNorm2d (bn2)            [32, 128, 28, 28]    [32, 128, 28, 28]    256                  True
# │    │    └─ReLU (relu)                  [32, 128, 28, 28]    [32, 128, 28, 28]    --                   --
# │    │    └─Conv2d (conv3)               [32, 128, 28, 28]    [32, 512, 28, 28]    65,536               True
# │    │    └─BatchNorm2d (bn3)            [32, 512, 28, 28]    [32, 512, 28, 28]    1,024                True
# │    │    └─ReLU (relu)                  [32, 512, 28, 28]    [32, 512, 28, 28]    --                   --
# │    └─Bottleneck (3)                    [32, 512, 28, 28]    [32, 512, 28, 28]    --                   True
# │    │    └─Conv2d (conv1)               [32, 512, 28, 28]    [32, 128, 28, 28]    65,536               True
# │    │    └─BatchNorm2d (bn1)            [32, 128, 28, 28]    [32, 128, 28, 28]    256                  True
# │    │    └─ReLU (relu)                  [32, 128, 28, 28]    [32, 128, 28, 28]    --                   --
# │    │    └─Conv2d (conv2)               [32, 128, 28, 28]    [32, 128, 28, 28]    147,456              True
# │    │    └─BatchNorm2d (bn2)            [32, 128, 28, 28]    [32, 128, 28, 28]    256                  True
# │    │    └─ReLU (relu)                  [32, 128, 28, 28]    [32, 128, 28, 28]    --                   --
# │    │    └─Conv2d (conv3)               [32, 128, 28, 28]    [32, 512, 28, 28]    65,536               True
# │    │    └─BatchNorm2d (bn3)            [32, 512, 28, 28]    [32, 512, 28, 28]    1,024                True
# │    │    └─ReLU (relu)                  [32, 512, 28, 28]    [32, 512, 28, 28]    --                   --
# ├─Sequential (layer3)                    [32, 512, 28, 28]    [32, 1024, 14, 14]   --                   True
# │    └─Bottleneck (0)                    [32, 512, 28, 28]    [32, 1024, 14, 14]   --                   True
# │    │    └─Conv2d (conv1)               [32, 512, 28, 28]    [32, 256, 28, 28]    131,072              True
# │    │    └─BatchNorm2d (bn1)            [32, 256, 28, 28]    [32, 256, 28, 28]    512                  True
# │    │    └─ReLU (relu)                  [32, 256, 28, 28]    [32, 256, 28, 28]    --                   --
# │    │    └─Conv2d (conv2)               [32, 256, 28, 28]    [32, 256, 14, 14]    589,824              True
# │    │    └─BatchNorm2d (bn2)            [32, 256, 14, 14]    [32, 256, 14, 14]    512                  True
# │    │    └─ReLU (relu)                  [32, 256, 14, 14]    [32, 256, 14, 14]    --                   --
# │    │    └─Conv2d (conv3)               [32, 256, 14, 14]    [32, 1024, 14, 14]   262,144              True
# │    │    └─BatchNorm2d (bn3)            [32, 1024, 14, 14]   [32, 1024, 14, 14]   2,048                True
# │    │    └─Sequential (downsample)      [32, 512, 28, 28]    [32, 1024, 14, 14]   526,336              True
# │    │    └─ReLU (relu)                  [32, 1024, 14, 14]   [32, 1024, 14, 14]   --                   --
# │    └─Bottleneck (1)                    [32, 1024, 14, 14]   [32, 1024, 14, 14]   --                   True
# │    │    └─Conv2d (conv1)               [32, 1024, 14, 14]   [32, 256, 14, 14]    262,144              True
# │    │    └─BatchNorm2d (bn1)            [32, 256, 14, 14]    [32, 256, 14, 14]    512                  True
# │    │    └─ReLU (relu)                  [32, 256, 14, 14]    [32, 256, 14, 14]    --                   --
# │    │    └─Conv2d (conv2)               [32, 256, 14, 14]    [32, 256, 14, 14]    589,824              True
# │    │    └─BatchNorm2d (bn2)            [32, 256, 14, 14]    [32, 256, 14, 14]    512                  True
# │    │    └─ReLU (relu)                  [32, 256, 14, 14]    [32, 256, 14, 14]    --                   --
# │    │    └─Conv2d (conv3)               [32, 256, 14, 14]    [32, 1024, 14, 14]   262,144              True
# │    │    └─BatchNorm2d (bn3)            [32, 1024, 14, 14]   [32, 1024, 14, 14]   2,048                True
# │    │    └─ReLU (relu)                  [32, 1024, 14, 14]   [32, 1024, 14, 14]   --                   --
# │    └─Bottleneck (2)                    [32, 1024, 14, 14]   [32, 1024, 14, 14]   --                   True
# │    │    └─Conv2d (conv1)               [32, 1024, 14, 14]   [32, 256, 14, 14]    262,144              True
# │    │    └─BatchNorm2d (bn1)            [32, 256, 14, 14]    [32, 256, 14, 14]    512                  True
# │    │    └─ReLU (relu)                  [32, 256, 14, 14]    [32, 256, 14, 14]    --                   --
# │    │    └─Conv2d (conv2)               [32, 256, 14, 14]    [32, 256, 14, 14]    589,824              True
# │    │    └─BatchNorm2d (bn2)            [32, 256, 14, 14]    [32, 256, 14, 14]    512                  True
# │    │    └─ReLU (relu)                  [32, 256, 14, 14]    [32, 256, 14, 14]    --                   --
# │    │    └─Conv2d (conv3)               [32, 256, 14, 14]    [32, 1024, 14, 14]   262,144              True
# │    │    └─BatchNorm2d (bn3)            [32, 1024, 14, 14]   [32, 1024, 14, 14]   2,048                True
# │    │    └─ReLU (relu)                  [32, 1024, 14, 14]   [32, 1024, 14, 14]   --                   --
# │    └─Bottleneck (3)                    [32, 1024, 14, 14]   [32, 1024, 14, 14]   --                   True
# │    │    └─Conv2d (conv1)               [32, 1024, 14, 14]   [32, 256, 14, 14]    262,144              True
# │    │    └─BatchNorm2d (bn1)            [32, 256, 14, 14]    [32, 256, 14, 14]    512                  True
# │    │    └─ReLU (relu)                  [32, 256, 14, 14]    [32, 256, 14, 14]    --                   --
# │    │    └─Conv2d (conv2)               [32, 256, 14, 14]    [32, 256, 14, 14]    589,824              True
# │    │    └─BatchNorm2d (bn2)            [32, 256, 14, 14]    [32, 256, 14, 14]    512                  True
# │    │    └─ReLU (relu)                  [32, 256, 14, 14]    [32, 256, 14, 14]    --                   --
# │    │    └─Conv2d (conv3)               [32, 256, 14, 14]    [32, 1024, 14, 14]   262,144              True
# │    │    └─BatchNorm2d (bn3)            [32, 1024, 14, 14]   [32, 1024, 14, 14]   2,048                True
# │    │    └─ReLU (relu)                  [32, 1024, 14, 14]   [32, 1024, 14, 14]   --                   --
# │    └─Bottleneck (4)                    [32, 1024, 14, 14]   [32, 1024, 14, 14]   --                   True
# │    │    └─Conv2d (conv1)               [32, 1024, 14, 14]   [32, 256, 14, 14]    262,144              True
# │    │    └─BatchNorm2d (bn1)            [32, 256, 14, 14]    [32, 256, 14, 14]    512                  True
# │    │    └─ReLU (relu)                  [32, 256, 14, 14]    [32, 256, 14, 14]    --                   --
# │    │    └─Conv2d (conv2)               [32, 256, 14, 14]    [32, 256, 14, 14]    589,824              True
# │    │    └─BatchNorm2d (bn2)            [32, 256, 14, 14]    [32, 256, 14, 14]    512                  True
# │    │    └─ReLU (relu)                  [32, 256, 14, 14]    [32, 256, 14, 14]    --                   --
# │    │    └─Conv2d (conv3)               [32, 256, 14, 14]    [32, 1024, 14, 14]   262,144              True
# │    │    └─BatchNorm2d (bn3)            [32, 1024, 14, 14]   [32, 1024, 14, 14]   2,048                True
# │    │    └─ReLU (relu)                  [32, 1024, 14, 14]   [32, 1024, 14, 14]   --                   --
# │    └─Bottleneck (5)                    [32, 1024, 14, 14]   [32, 1024, 14, 14]   --                   True
# │    │    └─Conv2d (conv1)               [32, 1024, 14, 14]   [32, 256, 14, 14]    262,144              True
# │    │    └─BatchNorm2d (bn1)            [32, 256, 14, 14]    [32, 256, 14, 14]    512                  True
# │    │    └─ReLU (relu)                  [32, 256, 14, 14]    [32, 256, 14, 14]    --                   --
# │    │    └─Conv2d (conv2)               [32, 256, 14, 14]    [32, 256, 14, 14]    589,824              True
# │    │    └─BatchNorm2d (bn2)            [32, 256, 14, 14]    [32, 256, 14, 14]    512                  True
# │    │    └─ReLU (relu)                  [32, 256, 14, 14]    [32, 256, 14, 14]    --                   --
# │    │    └─Conv2d (conv3)               [32, 256, 14, 14]    [32, 1024, 14, 14]   262,144              True
# │    │    └─BatchNorm2d (bn3)            [32, 1024, 14, 14]   [32, 1024, 14, 14]   2,048                True
# │    │    └─ReLU (relu)                  [32, 1024, 14, 14]   [32, 1024, 14, 14]   --                   --
# ├─Sequential (layer4)                    [32, 1024, 14, 14]   [32, 2048, 7, 7]     --                   True
# │    └─Bottleneck (0)                    [32, 1024, 14, 14]   [32, 2048, 7, 7]     --                   True
# │    │    └─Conv2d (conv1)               [32, 1024, 14, 14]   [32, 512, 14, 14]    524,288              True
# │    │    └─BatchNorm2d (bn1)            [32, 512, 14, 14]    [32, 512, 14, 14]    1,024                True
# │    │    └─ReLU (relu)                  [32, 512, 14, 14]    [32, 512, 14, 14]    --                   --
# │    │    └─Conv2d (conv2)               [32, 512, 14, 14]    [32, 512, 7, 7]      2,359,296            True
# │    │    └─BatchNorm2d (bn2)            [32, 512, 7, 7]      [32, 512, 7, 7]      1,024                True
# │    │    └─ReLU (relu)                  [32, 512, 7, 7]      [32, 512, 7, 7]      --                   --
# │    │    └─Conv2d (conv3)               [32, 512, 7, 7]      [32, 2048, 7, 7]     1,048,576            True
# │    │    └─BatchNorm2d (bn3)            [32, 2048, 7, 7]     [32, 2048, 7, 7]     4,096                True
# │    │    └─Sequential (downsample)      [32, 1024, 14, 14]   [32, 2048, 7, 7]     2,101,248            True
# │    │    └─ReLU (relu)                  [32, 2048, 7, 7]     [32, 2048, 7, 7]     --                   --
# │    └─Bottleneck (1)                    [32, 2048, 7, 7]     [32, 2048, 7, 7]     --                   True
# │    │    └─Conv2d (conv1)               [32, 2048, 7, 7]     [32, 512, 7, 7]      1,048,576            True
# │    │    └─BatchNorm2d (bn1)            [32, 512, 7, 7]      [32, 512, 7, 7]      1,024                True
# │    │    └─ReLU (relu)                  [32, 512, 7, 7]      [32, 512, 7, 7]      --                   --
# │    │    └─Conv2d (conv2)               [32, 512, 7, 7]      [32, 512, 7, 7]      2,359,296            True
# │    │    └─BatchNorm2d (bn2)            [32, 512, 7, 7]      [32, 512, 7, 7]      1,024                True
# │    │    └─ReLU (relu)                  [32, 512, 7, 7]      [32, 512, 7, 7]      --                   --
# │    │    └─Conv2d (conv3)               [32, 512, 7, 7]      [32, 2048, 7, 7]     1,048,576            True
# │    │    └─BatchNorm2d (bn3)            [32, 2048, 7, 7]     [32, 2048, 7, 7]     4,096                True
# │    │    └─ReLU (relu)                  [32, 2048, 7, 7]     [32, 2048, 7, 7]     --                   --
# │    └─Bottleneck (2)                    [32, 2048, 7, 7]     [32, 2048, 7, 7]     --                   True
# │    │    └─Conv2d (conv1)               [32, 2048, 7, 7]     [32, 512, 7, 7]      1,048,576            True
# │    │    └─BatchNorm2d (bn1)            [32, 512, 7, 7]      [32, 512, 7, 7]      1,024                True
# │    │    └─ReLU (relu)                  [32, 512, 7, 7]      [32, 512, 7, 7]      --                   --
# │    │    └─Conv2d (conv2)               [32, 512, 7, 7]      [32, 512, 7, 7]      2,359,296            True
# │    │    └─BatchNorm2d (bn2)            [32, 512, 7, 7]      [32, 512, 7, 7]      1,024                True
# │    │    └─ReLU (relu)                  [32, 512, 7, 7]      [32, 512, 7, 7]      --                   --
# │    │    └─Conv2d (conv3)               [32, 512, 7, 7]      [32, 2048, 7, 7]     1,048,576            True
# │    │    └─BatchNorm2d (bn3)            [32, 2048, 7, 7]     [32, 2048, 7, 7]     4,096                True
# │    │    └─ReLU (relu)                  [32, 2048, 7, 7]     [32, 2048, 7, 7]     --                   --
# ├─AdaptiveAvgPool2d (avgpool)            [32, 2048, 7, 7]     [32, 2048, 1, 1]     --                   --
# ├─Linear (fc)                            [32, 2048]           [32, 1000]           2,049,000            True
# ========================================================================================================================
# Total params: 25,557,032
# Trainable params: 25,557,032
# Non-trainable params: 0
# Total mult-adds (G): 130.86
# ========================================================================================================================
# Input size (MB): 19.27
# Forward/backward pass size (MB): 5690.62
# Params size (MB): 102.23
# Estimated Total Size (MB): 5812.11
# ========================================================================================================================

# %% [markdown]
# ### As you can see, it is a huge model with over 25 parameters.
# ### For our use, we will have to freeze the feature parameters and only train the classifying layer.

# %%
for param in model.parameters():
    param.requires_grad = False

# %%
torch.manual_seed(42)
torch.cuda.manual_seed(42)

model.fc = torch.nn.Sequential(
    torch.nn.Linear(in_features=2048, 
                    out_features=2, # same number of output units as our number of classes
                    bias=True)).to(device)

# %% [markdown]
# ### Let's see whether the change took place correctly.

# %%
torchinfo.summary(model=model, 
        input_size=(32, 3, 224, 224),
        col_names=["input_size", "output_size", "num_params", "trainable"],
        col_width=20,
        row_settings=["var_names"]
)
# Out:
# ========================================================================================================================
# Layer (type (var_name))                  Input Shape          Output Shape         Param #              Trainable
# ========================================================================================================================
# ResNet (ResNet)                          [32, 3, 224, 224]    [32, 2]              --                   Partial
# ├─Conv2d (conv1)                         [32, 3, 224, 224]    [32, 64, 112, 112]   (9,408)              False
# ├─BatchNorm2d (bn1)                      [32, 64, 112, 112]   [32, 64, 112, 112]   (128)                False
# ├─ReLU (relu)                            [32, 64, 112, 112]   [32, 64, 112, 112]   --                   --
# ├─MaxPool2d (maxpool)                    [32, 64, 112, 112]   [32, 64, 56, 56]     --                   --
# ├─Sequential (layer1)                    [32, 64, 56, 56]     [32, 256, 56, 56]    --                   False
# │    └─Bottleneck (0)                    [32, 64, 56, 56]     [32, 256, 56, 56]    --                   False
# │    │    └─Conv2d (conv1)               [32, 64, 56, 56]     [32, 64, 56, 56]     (4,096)              False
# │    │    └─BatchNorm2d (bn1)            [32, 64, 56, 56]     [32, 64, 56, 56]     (128)                False
# │    │    └─ReLU (relu)                  [32, 64, 56, 56]     [32, 64, 56, 56]     --                   --
# │    │    └─Conv2d (conv2)               [32, 64, 56, 56]     [32, 64, 56, 56]     (36,864)             False
# │    │    └─BatchNorm2d (bn2)            [32, 64, 56, 56]     [32, 64, 56, 56]     (128)                False
# │    │    └─ReLU (relu)                  [32, 64, 56, 56]     [32, 64, 56, 56]     --                   --
# │    │    └─Conv2d (conv3)               [32, 64, 56, 56]     [32, 256, 56, 56]    (16,384)             False
# │    │    └─BatchNorm2d (bn3)            [32, 256, 56, 56]    [32, 256, 56, 56]    (512)                False
# │    │    └─Sequential (downsample)      [32, 64, 56, 56]     [32, 256, 56, 56]    (16,896)             False
# │    │    └─ReLU (relu)                  [32, 256, 56, 56]    [32, 256, 56, 56]    --                   --
# │    └─Bottleneck (1)                    [32, 256, 56, 56]    [32, 256, 56, 56]    --                   False
# │    │    └─Conv2d (conv1)               [32, 256, 56, 56]    [32, 64, 56, 56]     (16,384)             False
# │    │    └─BatchNorm2d (bn1)            [32, 64, 56, 56]     [32, 64, 56, 56]     (128)                False
# │    │    └─ReLU (relu)                  [32, 64, 56, 56]     [32, 64, 56, 56]     --                   --
# │    │    └─Conv2d (conv2)               [32, 64, 56, 56]     [32, 64, 56, 56]     (36,864)             False
# │    │    └─BatchNorm2d (bn2)            [32, 64, 56, 56]     [32, 64, 56, 56]     (128)                False
# │    │    └─ReLU (relu)                  [32, 64, 56, 56]     [32, 64, 56, 56]     --                   --
# │    │    └─Conv2d (conv3)               [32, 64, 56, 56]     [32, 256, 56, 56]    (16,384)             False
# │    │    └─BatchNorm2d (bn3)            [32, 256, 56, 56]    [32, 256, 56, 56]    (512)                False
# │    │    └─ReLU (relu)                  [32, 256, 56, 56]    [32, 256, 56, 56]    --                   --
# │    └─Bottleneck (2)                    [32, 256, 56, 56]    [32, 256, 56, 56]    --                   False
# │    │    └─Conv2d (conv1)               [32, 256, 56, 56]    [32, 64, 56, 56]     (16,384)             False
# │    │    └─BatchNorm2d (bn1)            [32, 64, 56, 56]     [32, 64, 56, 56]     (128)                False
# │    │    └─ReLU (relu)                  [32, 64, 56, 56]     [32, 64, 56, 56]     --                   --
# │    │    └─Conv2d (conv2)               [32, 64, 56, 56]     [32, 64, 56, 56]     (36,864)             False
# │    │    └─BatchNorm2d (bn2)            [32, 64, 56, 56]     [32, 64, 56, 56]     (128)                False
# │    │    └─ReLU (relu)                  [32, 64, 56, 56]     [32, 64, 56, 56]     --                   --
# │    │    └─Conv2d (conv3)               [32, 64, 56, 56]     [32, 256, 56, 56]    (16,384)             False
# │    │    └─BatchNorm2d (bn3)            [32, 256, 56, 56]    [32, 256, 56, 56]    (512)                False
# │    │    └─ReLU (relu)                  [32, 256, 56, 56]    [32, 256, 56, 56]    --                   --
# ├─Sequential (layer2)                    [32, 256, 56, 56]    [32, 512, 28, 28]    --                   False
# │    └─Bottleneck (0)                    [32, 256, 56, 56]    [32, 512, 28, 28]    --                   False
# │    │    └─Conv2d (conv1)               [32, 256, 56, 56]    [32, 128, 56, 56]    (32,768)             False
# │    │    └─BatchNorm2d (bn1)            [32, 128, 56, 56]    [32, 128, 56, 56]    (256)                False
# │    │    └─ReLU (relu)                  [32, 128, 56, 56]    [32, 128, 56, 56]    --                   --
# │    │    └─Conv2d (conv2)               [32, 128, 56, 56]    [32, 128, 28, 28]    (147,456)            False
# │    │    └─BatchNorm2d (bn2)            [32, 128, 28, 28]    [32, 128, 28, 28]    (256)                False
# │    │    └─ReLU (relu)                  [32, 128, 28, 28]    [32, 128, 28, 28]    --                   --
# │    │    └─Conv2d (conv3)               [32, 128, 28, 28]    [32, 512, 28, 28]    (65,536)             False
# │    │    └─BatchNorm2d (bn3)            [32, 512, 28, 28]    [32, 512, 28, 28]    (1,024)              False
# │    │    └─Sequential (downsample)      [32, 256, 56, 56]    [32, 512, 28, 28]    (132,096)            False
# │    │    └─ReLU (relu)                  [32, 512, 28, 28]    [32, 512, 28, 28]    --                   --
# │    └─Bottleneck (1)                    [32, 512, 28, 28]    [32, 512, 28, 28]    --                   False
# │    │    └─Conv2d (conv1)               [32, 512, 28, 28]    [32, 128, 28, 28]    (65,536)             False
# │    │    └─BatchNorm2d (bn1)            [32, 128, 28, 28]    [32, 128, 28, 28]    (256)                False
# │    │    └─ReLU (relu)                  [32, 128, 28, 28]    [32, 128, 28, 28]    --                   --
# │    │    └─Conv2d (conv2)               [32, 128, 28, 28]    [32, 128, 28, 28]    (147,456)            False
# │    │    └─BatchNorm2d (bn2)            [32, 128, 28, 28]    [32, 128, 28, 28]    (256)                False
# │    │    └─ReLU (relu)                  [32, 128, 28, 28]    [32, 128, 28, 28]    --                   --
# │    │    └─Conv2d (conv3)               [32, 128, 28, 28]    [32, 512, 28, 28]    (65,536)             False
# │    │    └─BatchNorm2d (bn3)            [32, 512, 28, 28]    [32, 512, 28, 28]    (1,024)              False
# │    │    └─ReLU (relu)                  [32, 512, 28, 28]    [32, 512, 28, 28]    --                   --
# │    └─Bottleneck (2)                    [32, 512, 28, 28]    [32, 512, 28, 28]    --                   False
# │    │    └─Conv2d (conv1)               [32, 512, 28, 28]    [32, 128, 28, 28]    (65,536)             False
# │    │    └─BatchNorm2d (bn1)            [32, 128, 28, 28]    [32, 128, 28, 28]    (256)                False
# │    │    └─ReLU (relu)                  [32, 128, 28, 28]    [32, 128, 28, 28]    --                   --
# │    │    └─Conv2d (conv2)               [32, 128, 28, 28]    [32, 128, 28, 28]    (147,456)            False
# │    │    └─BatchNorm2d (bn2)            [32, 128, 28, 28]    [32, 128, 28, 28]    (256)                False
# │    │    └─ReLU (relu)                  [32, 128, 28, 28]    [32, 128, 28, 28]    --                   --
# │    │    └─Conv2d (conv3)               [32, 128, 28, 28]    [32, 512, 28, 28]    (65,536)             False
# │    │    └─BatchNorm2d (bn3)            [32, 512, 28, 28]    [32, 512, 28, 28]    (1,024)              False
# │    │    └─ReLU (relu)                  [32, 512, 28, 28]    [32, 512, 28, 28]    --                   --
# │    └─Bottleneck (3)                    [32, 512, 28, 28]    [32, 512, 28, 28]    --                   False
# │    │    └─Conv2d (conv1)               [32, 512, 28, 28]    [32, 128, 28, 28]    (65,536)             False
# │    │    └─BatchNorm2d (bn1)            [32, 128, 28, 28]    [32, 128, 28, 28]    (256)                False
# │    │    └─ReLU (relu)                  [32, 128, 28, 28]    [32, 128, 28, 28]    --                   --
# │    │    └─Conv2d (conv2)               [32, 128, 28, 28]    [32, 128, 28, 28]    (147,456)            False
# │    │    └─BatchNorm2d (bn2)            [32, 128, 28, 28]    [32, 128, 28, 28]    (256)                False
# │    │    └─ReLU (relu)                  [32, 128, 28, 28]    [32, 128, 28, 28]    --                   --
# │    │    └─Conv2d (conv3)               [32, 128, 28, 28]    [32, 512, 28, 28]    (65,536)             False
# │    │    └─BatchNorm2d (bn3)            [32, 512, 28, 28]    [32, 512, 28, 28]    (1,024)              False
# │    │    └─ReLU (relu)                  [32, 512, 28, 28]    [32, 512, 28, 28]    --                   --
# ├─Sequential (layer3)                    [32, 512, 28, 28]    [32, 1024, 14, 14]   --                   False
# │    └─Bottleneck (0)                    [32, 512, 28, 28]    [32, 1024, 14, 14]   --                   False
# │    │    └─Conv2d (conv1)               [32, 512, 28, 28]    [32, 256, 28, 28]    (131,072)            False
# │    │    └─BatchNorm2d (bn1)            [32, 256, 28, 28]    [32, 256, 28, 28]    (512)                False
# │    │    └─ReLU (relu)                  [32, 256, 28, 28]    [32, 256, 28, 28]    --                   --
# │    │    └─Conv2d (conv2)               [32, 256, 28, 28]    [32, 256, 14, 14]    (589,824)            False
# │    │    └─BatchNorm2d (bn2)            [32, 256, 14, 14]    [32, 256, 14, 14]    (512)                False
# │    │    └─ReLU (relu)                  [32, 256, 14, 14]    [32, 256, 14, 14]    --                   --
# │    │    └─Conv2d (conv3)               [32, 256, 14, 14]    [32, 1024, 14, 14]   (262,144)            False
# │    │    └─BatchNorm2d (bn3)            [32, 1024, 14, 14]   [32, 1024, 14, 14]   (2,048)              False
# │    │    └─Sequential (downsample)      [32, 512, 28, 28]    [32, 1024, 14, 14]   (526,336)            False
# │    │    └─ReLU (relu)                  [32, 1024, 14, 14]   [32, 1024, 14, 14]   --                   --
# │    └─Bottleneck (1)                    [32, 1024, 14, 14]   [32, 1024, 14, 14]   --                   False
# │    │    └─Conv2d (conv1)               [32, 1024, 14, 14]   [32, 256, 14, 14]    (262,144)            False
# │    │    └─BatchNorm2d (bn1)            [32, 256, 14, 14]    [32, 256, 14, 14]    (512)                False
# │    │    └─ReLU (relu)                  [32, 256, 14, 14]    [32, 256, 14, 14]    --                   --
# │    │    └─Conv2d (conv2)               [32, 256, 14, 14]    [32, 256, 14, 14]    (589,824)            False
# │    │    └─BatchNorm2d (bn2)            [32, 256, 14, 14]    [32, 256, 14, 14]    (512)                False
# │    │    └─ReLU (relu)                  [32, 256, 14, 14]    [32, 256, 14, 14]    --                   --
# │    │    └─Conv2d (conv3)               [32, 256, 14, 14]    [32, 1024, 14, 14]   (262,144)            False
# │    │    └─BatchNorm2d (bn3)            [32, 1024, 14, 14]   [32, 1024, 14, 14]   (2,048)              False
# │    │    └─ReLU (relu)                  [32, 1024, 14, 14]   [32, 1024, 14, 14]   --                   --
# │    └─Bottleneck (2)                    [32, 1024, 14, 14]   [32, 1024, 14, 14]   --                   False
# │    │    └─Conv2d (conv1)               [32, 1024, 14, 14]   [32, 256, 14, 14]    (262,144)            False
# │    │    └─BatchNorm2d (bn1)            [32, 256, 14, 14]    [32, 256, 14, 14]    (512)                False
# │    │    └─ReLU (relu)                  [32, 256, 14, 14]    [32, 256, 14, 14]    --                   --
# │    │    └─Conv2d (conv2)               [32, 256, 14, 14]    [32, 256, 14, 14]    (589,824)            False
# │    │    └─BatchNorm2d (bn2)            [32, 256, 14, 14]    [32, 256, 14, 14]    (512)                False
# │    │    └─ReLU (relu)                  [32, 256, 14, 14]    [32, 256, 14, 14]    --                   --
# │    │    └─Conv2d (conv3)               [32, 256, 14, 14]    [32, 1024, 14, 14]   (262,144)            False
# │    │    └─BatchNorm2d (bn3)            [32, 1024, 14, 14]   [32, 1024, 14, 14]   (2,048)              False
# │    │    └─ReLU (relu)                  [32, 1024, 14, 14]   [32, 1024, 14, 14]   --                   --
# │    └─Bottleneck (3)                    [32, 1024, 14, 14]   [32, 1024, 14, 14]   --                   False
# │    │    └─Conv2d (conv1)               [32, 1024, 14, 14]   [32, 256, 14, 14]    (262,144)            False
# │    │    └─BatchNorm2d (bn1)            [32, 256, 14, 14]    [32, 256, 14, 14]    (512)                False
# │    │    └─ReLU (relu)                  [32, 256, 14, 14]    [32, 256, 14, 14]    --                   --
# │    │    └─Conv2d (conv2)               [32, 256, 14, 14]    [32, 256, 14, 14]    (589,824)            False
# │    │    └─BatchNorm2d (bn2)            [32, 256, 14, 14]    [32, 256, 14, 14]    (512)                False
# │    │    └─ReLU (relu)                  [32, 256, 14, 14]    [32, 256, 14, 14]    --                   --
# │    │    └─Conv2d (conv3)               [32, 256, 14, 14]    [32, 1024, 14, 14]   (262,144)            False
# │    │    └─BatchNorm2d (bn3)            [32, 1024, 14, 14]   [32, 1024, 14, 14]   (2,048)              False
# │    │    └─ReLU (relu)                  [32, 1024, 14, 14]   [32, 1024, 14, 14]   --                   --
# │    └─Bottleneck (4)                    [32, 1024, 14, 14]   [32, 1024, 14, 14]   --                   False
# │    │    └─Conv2d (conv1)               [32, 1024, 14, 14]   [32, 256, 14, 14]    (262,144)            False
# │    │    └─BatchNorm2d (bn1)            [32, 256, 14, 14]    [32, 256, 14, 14]    (512)                False
# │    │    └─ReLU (relu)                  [32, 256, 14, 14]    [32, 256, 14, 14]    --                   --
# │    │    └─Conv2d (conv2)               [32, 256, 14, 14]    [32, 256, 14, 14]    (589,824)            False
# │    │    └─BatchNorm2d (bn2)            [32, 256, 14, 14]    [32, 256, 14, 14]    (512)                False
# │    │    └─ReLU (relu)                  [32, 256, 14, 14]    [32, 256, 14, 14]    --                   --
# │    │    └─Conv2d (conv3)               [32, 256, 14, 14]    [32, 1024, 14, 14]   (262,144)            False
# │    │    └─BatchNorm2d (bn3)            [32, 1024, 14, 14]   [32, 1024, 14, 14]   (2,048)              False
# │    │    └─ReLU (relu)                  [32, 1024, 14, 14]   [32, 1024, 14, 14]   --                   --
# │    └─Bottleneck (5)                    [32, 1024, 14, 14]   [32, 1024, 14, 14]   --                   False
# │    │    └─Conv2d (conv1)               [32, 1024, 14, 14]   [32, 256, 14, 14]    (262,144)            False
# │    │    └─BatchNorm2d (bn1)            [32, 256, 14, 14]    [32, 256, 14, 14]    (512)                False
# │    │    └─ReLU (relu)                  [32, 256, 14, 14]    [32, 256, 14, 14]    --                   --
# │    │    └─Conv2d (conv2)               [32, 256, 14, 14]    [32, 256, 14, 14]    (589,824)            False
# │    │    └─BatchNorm2d (bn2)            [32, 256, 14, 14]    [32, 256, 14, 14]    (512)                False
# │    │    └─ReLU (relu)                  [32, 256, 14, 14]    [32, 256, 14, 14]    --                   --
# │    │    └─Conv2d (conv3)               [32, 256, 14, 14]    [32, 1024, 14, 14]   (262,144)            False
# │    │    └─BatchNorm2d (bn3)            [32, 1024, 14, 14]   [32, 1024, 14, 14]   (2,048)              False
# │    │    └─ReLU (relu)                  [32, 1024, 14, 14]   [32, 1024, 14, 14]   --                   --
# ├─Sequential (layer4)                    [32, 1024, 14, 14]   [32, 2048, 7, 7]     --                   False
# │    └─Bottleneck (0)                    [32, 1024, 14, 14]   [32, 2048, 7, 7]     --                   False
# │    │    └─Conv2d (conv1)               [32, 1024, 14, 14]   [32, 512, 14, 14]    (524,288)            False
# │    │    └─BatchNorm2d (bn1)            [32, 512, 14, 14]    [32, 512, 14, 14]    (1,024)              False
# │    │    └─ReLU (relu)                  [32, 512, 14, 14]    [32, 512, 14, 14]    --                   --
# │    │    └─Conv2d (conv2)               [32, 512, 14, 14]    [32, 512, 7, 7]      (2,359,296)          False
# │    │    └─BatchNorm2d (bn2)            [32, 512, 7, 7]      [32, 512, 7, 7]      (1,024)              False
# │    │    └─ReLU (relu)                  [32, 512, 7, 7]      [32, 512, 7, 7]      --                   --
# │    │    └─Conv2d (conv3)               [32, 512, 7, 7]      [32, 2048, 7, 7]     (1,048,576)          False
# │    │    └─BatchNorm2d (bn3)            [32, 2048, 7, 7]     [32, 2048, 7, 7]     (4,096)              False
# │    │    └─Sequential (downsample)      [32, 1024, 14, 14]   [32, 2048, 7, 7]     (2,101,248)          False
# │    │    └─ReLU (relu)                  [32, 2048, 7, 7]     [32, 2048, 7, 7]     --                   --
# │    └─Bottleneck (1)                    [32, 2048, 7, 7]     [32, 2048, 7, 7]     --                   False
# │    │    └─Conv2d (conv1)               [32, 2048, 7, 7]     [32, 512, 7, 7]      (1,048,576)          False
# │    │    └─BatchNorm2d (bn1)            [32, 512, 7, 7]      [32, 512, 7, 7]      (1,024)              False
# │    │    └─ReLU (relu)                  [32, 512, 7, 7]      [32, 512, 7, 7]      --                   --
# │    │    └─Conv2d (conv2)               [32, 512, 7, 7]      [32, 512, 7, 7]      (2,359,296)          False
# │    │    └─BatchNorm2d (bn2)            [32, 512, 7, 7]      [32, 512, 7, 7]      (1,024)              False
# │    │    └─ReLU (relu)                  [32, 512, 7, 7]      [32, 512, 7, 7]      --                   --
# │    │    └─Conv2d (conv3)               [32, 512, 7, 7]      [32, 2048, 7, 7]     (1,048,576)          False
# │    │    └─BatchNorm2d (bn3)            [32, 2048, 7, 7]     [32, 2048, 7, 7]     (4,096)              False
# │    │    └─ReLU (relu)                  [32, 2048, 7, 7]     [32, 2048, 7, 7]     --                   --
# │    └─Bottleneck (2)                    [32, 2048, 7, 7]     [32, 2048, 7, 7]     --                   False
# │    │    └─Conv2d (conv1)               [32, 2048, 7, 7]     [32, 512, 7, 7]      (1,048,576)          False
# │    │    └─BatchNorm2d (bn1)            [32, 512, 7, 7]      [32, 512, 7, 7]      (1,024)              False
# │    │    └─ReLU (relu)                  [32, 512, 7, 7]      [32, 512, 7, 7]      --                   --
# │    │    └─Conv2d (conv2)               [32, 512, 7, 7]      [32, 512, 7, 7]      (2,359,296)          False
# │    │    └─BatchNorm2d (bn2)            [32, 512, 7, 7]      [32, 512, 7, 7]      (1,024)              False
# │    │    └─ReLU (relu)                  [32, 512, 7, 7]      [32, 512, 7, 7]      --                   --
# │    │    └─Conv2d (conv3)               [32, 512, 7, 7]      [32, 2048, 7, 7]     (1,048,576)          False
# │    │    └─BatchNorm2d (bn3)            [32, 2048, 7, 7]     [32, 2048, 7, 7]     (4,096)              False
# │    │    └─ReLU (relu)                  [32, 2048, 7, 7]     [32, 2048, 7, 7]     --                   --
# ├─AdaptiveAvgPool2d (avgpool)            [32, 2048, 7, 7]     [32, 2048, 1, 1]     --                   --
# ├─Sequential (fc)                        [32, 2048]           [32, 2]              --                   True
# │    └─Linear (0)                        [32, 2048]           [32, 2]              4,098                True
# ========================================================================================================================
# Total params: 23,512,130
# Trainable params: 4,098
# Non-trainable params: 23,508,032
# Total mult-adds (G): 130.79
# ========================================================================================================================
# Input size (MB): 19.27
# Forward/backward pass size (MB): 5690.36
# Params size (MB): 94.05
# Estimated Total Size (MB): 5803.68
# ========================================================================================================================

# %% [markdown]
# ### As we can see, only the last Sequential layer has trainable parameters.
# ### Thus, the number of trainable params dropped down from over 25 million to just 4098 parameters.
# ### We are going to hopefully achieve better results with this pretrained model.

# %%
# Setup loss function and optimizer
model = model 
lf = nn.BCEWithLogitsLoss()
optimizer = torch.optim.SGD(params=model.parameters(), lr=0.001)

epochs = 100
acc_fn = Accuracy(task='binary').to(device)
train_loss_arr = []
test_loss_arr = []
test_acc_arr = []

for epoch in range(epochs):
    train_loss = 0
    
    for batch, (X,y) in enumerate(train_dataloader_custom):
            
        X = X.to(device)
        y = y.to(device)
        model.train()
        
        # Forward
        y_pred = model(X)
        
        # Calculate loss
        loss = lf(y_pred, y)
        train_loss += loss
        
        # Zero grad
        optimizer.zero_grad()
        
        # Loss backward
        loss.backward()
        
        # Optimizer step
        optimizer.step()
    
    train_loss/=len(train_dataloader_custom)
    train_loss_arr.append(train_loss.cpu().detach().numpy())
    
    test_loss, test_acc= 0, 0
    model.eval() 
    with torch.inference_mode():
        for batch, (X,y) in enumerate(test_dataloader_custom):
            
            X = X.to(device)
            y = y.to(device)
            
            # Forward
            test_pred = model(X)
            
            # Calculate loss 
            test_loss += lf(test_pred, y)
            
            # Calculate accuracy 
            acc_fn.update(test_pred.argmax(dim=1).to(device), y.argmax(dim=1).to(device))
            test_acc += acc_fn.compute()
            
        test_loss /= len(test_dataloader_custom)
        test_loss_arr.append(test_loss.cpu().detach().numpy())
        test_acc /= len(test_dataloader_custom)
        test_acc_arr.append(test_acc.cpu().detach().numpy())
        
    print(f"\nEpoch: {epoch} | Train loss: {train_loss:.5f} | Test loss: {test_loss:.5f}, Test acc: {test_acc*100:.2f}%\n")
# Out:
# Epoch: 0 | Train loss: 0.63298 | Test loss: 0.55205, Test acc: 96.53%
#
#
# Epoch: 1 | Train loss: 0.53748 | Test loss: 0.46326, Test acc: 96.52%
#
#
# Epoch: 2 | Train loss: 0.47066 | Test loss: 0.39417, Test acc: 96.75%
#
#
# Epoch: 3 | Train loss: 0.42240 | Test loss: 0.34397, Test acc: 96.88%
#
#
# Epoch: 4 | Train loss: 0.38696 | Test loss: 0.30962, Test acc: 97.00%
#
#
# Epoch: 5 | Train loss: 0.35753 | Test loss: 0.28327, Test acc: 97.09%
#
#
# Epoch: 6 | Train loss: 0.33490 | Test loss: 0.25099, Test acc: 97.15%
#
#
# Epoch: 7 | Train loss: 0.31502 | Test loss: 0.23436, Test acc: 97.21%
#
#
# Epoch: 8 | Train loss: 0.30105 | Test loss: 0.22160, Test acc: 97.28%
#
#
# Epoch: 9 | Train loss: 0.28647 | Test loss: 0.21162, Test acc: 97.35%
#
#
# Epoch: 10 | Train loss: 0.27340 | Test loss: 0.20257, Test acc: 97.41%
#
#
# Epoch: 11 | Train loss: 0.26695 | Test loss: 0.19512, Test acc: 97.45%
#
#
# Epoch: 12 | Train loss: 0.25291 | Test loss: 0.17972, Test acc: 97.49%
#
#
# Epoch: 13 | Train loss: 0.24614 | Test loss: 0.17683, Test acc: 97.53%
#
#
# Epoch: 14 | Train loss: 0.24023 | Test loss: 0.16734, Test acc: 97.56%
#
#
# Epoch: 15 | Train loss: 0.23473 | Test loss: 0.15779, Test acc: 97.61%
#
#
# Epoch: 16 | Train loss: 0.22773 | Test loss: 0.15835, Test acc: 97.66%
#
#
# Epoch: 17 | Train loss: 0.22271 | Test loss: 0.14593, Test acc: 97.70%
#
#
# Epoch: 18 | Train loss: 0.22245 | Test loss: 0.13966, Test acc: 97.73%
#
#
# Epoch: 19 | Train loss: 0.21224 | Test loss: 0.13600, Test acc: 97.77%
#
#
# Epoch: 20 | Train loss: 0.21022 | Test loss: 0.13811, Test acc: 97.79%
#
#
# Epoch: 21 | Train loss: 0.20125 | Test loss: 0.13029, Test acc: 97.81%
#
#
# Epoch: 22 | Train loss: 0.20415 | Test loss: 0.13098, Test acc: 97.84%
#
#
# Epoch: 23 | Train loss: 0.19859 | Test loss: 0.13363, Test acc: 97.87%
#
#
# Epoch: 24 | Train loss: 0.19511 | Test loss: 0.11928, Test acc: 97.89%
#
#
# Epoch: 25 | Train loss: 0.19034 | Test loss: 0.12514, Test acc: 97.91%
#
#
# Epoch: 26 | Train loss: 0.19091 | Test loss: 0.11906, Test acc: 97.93%
#
#
# Epoch: 27 | Train loss: 0.18712 | Test loss: 0.11698, Test acc: 97.95%
#
#
# Epoch: 28 | Train loss: 0.18443 | Test loss: 0.11164, Test acc: 97.97%
#
#
# Epoch: 29 | Train loss: 0.18056 | Test loss: 0.10913, Test acc: 97.98%
#
#
# Epoch: 30 | Train loss: 0.17934 | Test loss: 0.10937, Test acc: 97.99%
#
#
# Epoch: 31 | Train loss: 0.17846 | Test loss: 0.10870, Test acc: 98.01%
#
#
# Epoch: 32 | Train loss: 0.17197 | Test loss: 0.10204, Test acc: 98.03%
#
#
# Epoch: 33 | Train loss: 0.17506 | Test loss: 0.10467, Test acc: 98.05%
#
#
# Epoch: 34 | Train loss: 0.17372 | Test loss: 0.10127, Test acc: 98.06%
#
#
# Epoch: 35 | Train loss: 0.16875 | Test loss: 0.10265, Test acc: 98.07%
#
#
# Epoch: 36 | Train loss: 0.16801 | Test loss: 0.10394, Test acc: 98.08%
#
#
# Epoch: 37 | Train loss: 0.16785 | Test loss: 0.10140, Test acc: 98.09%
#
#
# Epoch: 38 | Train loss: 0.16315 | Test loss: 0.09603, Test acc: 98.10%
#
#
# Epoch: 39 | Train loss: 0.16235 | Test loss: 0.09578, Test acc: 98.12%
#
#
# Epoch: 40 | Train loss: 0.16229 | Test loss: 0.09564, Test acc: 98.13%
#
#
# Epoch: 41 | Train loss: 0.15952 | Test loss: 0.08967, Test acc: 98.14%
#
#
# Epoch: 42 | Train loss: 0.16073 | Test loss: 0.09011, Test acc: 98.15%
#
#
# Epoch: 43 | Train loss: 0.15836 | Test loss: 0.08911, Test acc: 98.16%
#
#
# Epoch: 44 | Train loss: 0.15506 | Test loss: 0.08675, Test acc: 98.17%
#
#
# Epoch: 45 | Train loss: 0.15339 | Test loss: 0.08755, Test acc: 98.18%
#
#
# Epoch: 46 | Train loss: 0.15175 | Test loss: 0.08676, Test acc: 98.19%
#
#
# Epoch: 47 | Train loss: 0.15477 | Test loss: 0.08440, Test acc: 98.20%
#
#
# Epoch: 48 | Train loss: 0.15359 | Test loss: 0.08334, Test acc: 98.21%
#
#
# Epoch: 49 | Train loss: 0.15105 | Test loss: 0.08343, Test acc: 98.22%
#
#
# Epoch: 50 | Train loss: 0.14546 | Test loss: 0.08463, Test acc: 98.22%
#
#
# Epoch: 51 | Train loss: 0.14610 | Test loss: 0.08809, Test acc: 98.23%
#
#
# Epoch: 52 | Train loss: 0.14739 | Test loss: 0.08175, Test acc: 98.24%
#
#
# Epoch: 53 | Train loss: 0.14388 | Test loss: 0.08107, Test acc: 98.25%
#
#
# Epoch: 54 | Train loss: 0.14493 | Test loss: 0.08270, Test acc: 98.25%
#
#
# Epoch: 55 | Train loss: 0.14240 | Test loss: 0.07374, Test acc: 98.26%
#
#
# Epoch: 56 | Train loss: 0.14133 | Test loss: 0.07745, Test acc: 98.27%
#
#
# Epoch: 57 | Train loss: 0.14518 | Test loss: 0.07886, Test acc: 98.28%
#
#
# Epoch: 58 | Train loss: 0.13955 | Test loss: 0.08060, Test acc: 98.29%
#
#
# Epoch: 59 | Train loss: 0.13735 | Test loss: 0.07671, Test acc: 98.29%
#
#
# Epoch: 60 | Train loss: 0.14075 | Test loss: 0.07595, Test acc: 98.29%
#
#
# Epoch: 61 | Train loss: 0.14082 | Test loss: 0.07839, Test acc: 98.30%
#
#
# Epoch: 62 | Train loss: 0.13472 | Test loss: 0.07512, Test acc: 98.31%
#
#
# Epoch: 63 | Train loss: 0.13575 | Test loss: 0.07354, Test acc: 98.31%
#
#
# Epoch: 64 | Train loss: 0.13869 | Test loss: 0.07390, Test acc: 98.32%
#
#
# Epoch: 65 | Train loss: 0.13575 | Test loss: 0.07537, Test acc: 98.33%
#
#
# Epoch: 66 | Train loss: 0.13445 | Test loss: 0.06979, Test acc: 98.33%
#
#
# Epoch: 67 | Train loss: 0.13290 | Test loss: 0.07183, Test acc: 98.34%
#
#
# Epoch: 68 | Train loss: 0.13652 | Test loss: 0.06788, Test acc: 98.35%
#
#
# Epoch: 69 | Train loss: 0.13461 | Test loss: 0.07411, Test acc: 98.35%
#
#
# Epoch: 70 | Train loss: 0.13590 | Test loss: 0.06889, Test acc: 98.36%
#
#
# Epoch: 71 | Train loss: 0.13128 | Test loss: 0.06960, Test acc: 98.36%
#
#
# Epoch: 72 | Train loss: 0.12944 | Test loss: 0.07153, Test acc: 98.37%
#
#
# Epoch: 73 | Train loss: 0.13174 | Test loss: 0.06660, Test acc: 98.37%
#
#
# Epoch: 74 | Train loss: 0.13129 | Test loss: 0.06993, Test acc: 98.38%
#
#
# Epoch: 75 | Train loss: 0.13015 | Test loss: 0.06974, Test acc: 98.38%
#
#
# Epoch: 76 | Train loss: 0.12563 | Test loss: 0.06716, Test acc: 98.39%
#
#
# Epoch: 77 | Train loss: 0.12939 | Test loss: 0.06753, Test acc: 98.39%
#
#
# Epoch: 78 | Train loss: 0.12633 | Test loss: 0.07288, Test acc: 98.40%
#
#
# Epoch: 79 | Train loss: 0.12784 | Test loss: 0.06667, Test acc: 98.40%
#
#
# Epoch: 80 | Train loss: 0.12956 | Test loss: 0.06283, Test acc: 98.41%
#
#
# Epoch: 81 | Train loss: 0.12782 | Test loss: 0.06824, Test acc: 98.41%
#
#
# Epoch: 82 | Train loss: 0.12472 | Test loss: 0.06202, Test acc: 98.42%
#
#
# Epoch: 83 | Train loss: 0.12163 | Test loss: 0.06817, Test acc: 98.42%
#
#
# Epoch: 84 | Train loss: 0.12437 | Test loss: 0.06644, Test acc: 98.43%
#
#
# Epoch: 85 | Train loss: 0.12174 | Test loss: 0.06464, Test acc: 98.43%
#
#
# Epoch: 86 | Train loss: 0.12388 | Test loss: 0.06883, Test acc: 98.43%
#
#
# Epoch: 87 | Train loss: 0.12196 | Test loss: 0.06106, Test acc: 98.44%
#
#
# Epoch: 88 | Train loss: 0.12355 | Test loss: 0.06115, Test acc: 98.44%
#
#
# Epoch: 89 | Train loss: 0.11936 | Test loss: 0.06206, Test acc: 98.45%
#
#
# Epoch: 90 | Train loss: 0.12313 | Test loss: 0.06284, Test acc: 98.45%
#
#
# Epoch: 91 | Train loss: 0.11953 | Test loss: 0.06129, Test acc: 98.45%
#
#
# Epoch: 92 | Train loss: 0.12046 | Test loss: 0.06332, Test acc: 98.46%
#
#
# Epoch: 93 | Train loss: 0.12032 | Test loss: 0.06074, Test acc: 98.46%
#
#
# Epoch: 94 | Train loss: 0.11799 | Test loss: 0.06483, Test acc: 98.46%
#
#
# Epoch: 95 | Train loss: 0.11959 | Test loss: 0.05929, Test acc: 98.47%
#
#
# Epoch: 96 | Train loss: 0.12076 | Test loss: 0.05960, Test acc: 98.47%
#
#
# Epoch: 97 | Train loss: 0.11980 | Test loss: 0.06365, Test acc: 98.48%
#
#
# Epoch: 98 | Train loss: 0.11996 | Test loss: 0.05806, Test acc: 98.48%
#
#
# Epoch: 99 | Train loss: 0.11702 | Test loss: 0.06034, Test acc: 98.48%

# %%
plt.plot([i for i in range(epochs)], train_loss_arr, label='train_loss')
plt.plot([i for i in range(epochs)], test_loss_arr, label='test_loss')
plt.plot([i for i in range(epochs)], test_acc_arr, label='test accuracy')
plt.title('Evaluation')
plt.xlabel('Epochs')
plt.ylabel('Value')
plt.legend();

# %% [markdown]
# ### We can see the power of transfer learning from this!
# ### Albeit the simple CNN model performed fairly well, this was just a simple dataset.
# ### As the problem gets more complicated, never forget the power of transfer learning!
